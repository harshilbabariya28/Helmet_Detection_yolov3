# %% [markdown]
# ## first go to this website

# %% [markdown]
# https://roboflow.com/

# %% [markdown]
# ## then sign in or create an account on robolow

# %% [markdown]
# ## now click on create new project

# %% [markdown]
# ![Screenshot%202024-01-05%20113452.png](attachment:Screenshot%202024-01-05%20113452.png)

# %% [markdown]
# ## Now select object detection and fill the required spaces

# %% [markdown]
# ![Screenshot%202024-01-05%20114125.png](attachment:Screenshot%202024-01-05%20114125.png)

# %% [markdown]
# ## Now just drag and drop the files and draw the bounding box

# %% [markdown]
# ![Screenshot%202024-01-05%20114446.png](attachment:Screenshot%202024-01-05%20114446.png)

# %% [markdown]
# ![Screenshot%202024-01-05%20114550.png](attachment:Screenshot%202024-01-05%20114550.png)

# %% [markdown]
# ![Screenshot%202024-01-05%20114627.png](attachment:Screenshot%202024-01-05%20114627.png)

# %%
#now save and continue the process

# %% [markdown]
# ![Screenshot%202024-01-05%20114654.png](attachment:Screenshot%202024-01-05%20114654.png)

# %% [markdown]
# ![Screenshot%202024-01-05%20114720.png](attachment:Screenshot%202024-01-05%20114720.png)

# %% [markdown]
# ![Screenshot%202024-01-05%20114745.png](attachment:Screenshot%202024-01-05%20114745.png)

# %%
#click on export the dataset to export

# %% [markdown]
# ![Screenshot%202024-01-05%20114825.png](attachment:Screenshot%202024-01-05%20114825.png)
